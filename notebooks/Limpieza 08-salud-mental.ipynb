# %% [markdown]
# ### Limpieza de los ficheros de censo de locales.
# ## Los ficheros analizados son 08-salud-mental.csv. Se carga desde Kaggle
# # Tras analisis se decide no utilizar los datos del dataset por falta de relevancia con el estudio

# %%
import altair as alt

# Desactivar vegafusion si quedó activado accidentalmente
alt.data_transformers.enable("default", max_rows=None)

# Renderer compatible con JupyterLab / Anaconda
alt.renderers.enable("mimetype")
# Out:
# RendererRegistry.enable('mimetype')

# %%
# !pip install reverse_geocoder

# %%
import pandas as pd
import reverse_geocoder as rg
import kagglehub
from kagglehub import KaggleDatasetAdapter
from sklearn.decomposition import PCA
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import fcluster
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np



pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# Carga los datos raw disponibles en Kaggle. En la cuenta del alumno raquelahdo/ruido-datasets

file_path_08 = "08-48130_salud_mental.csv"


df_08 = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "raquelahdo/ruido-datasets",
  file_path_08,
    pandas_kwargs={"encoding": "utf-8-sig", "sep": ";"}
)

# %%
df_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 1 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Sexo	Edad	Salud mental	SI o NO_salud mental	periodo	Total  576 non-null    object
# dtypes: object(1)
# memory usage: 4.6+ KB

# %%
df_08.describe()
# Out:
#        Sexo\tEdad\tSalud mental\tSI o NO_salud mental\tperiodo\tTotal
# count                                                 576
# unique                                                576
# top     AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
# freq                                                    1

# %%
missing_values_08 = df_08.isnull().sum()
display(missing_values_08)
# Out:
# Sexo\tEdad\tSalud mental\tSI o NO_salud mental\tperiodo\tTotal    0
# dtype: int64

# %%
df_08.head()
# Out:
#   Sexo\tEdad\tSalud mental\tSI o NO_salud mental\tperiodo\tTotal
# 0  AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
# 1  AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
# 2  AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
# 3  AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
# 4  AMBOS SEXOS\tTOTAL\tPoco interés o alegría por...
